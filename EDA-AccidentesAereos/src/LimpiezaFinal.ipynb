# %% [markdown]
# Importo las librerias que crea necesarias para la limpieza de datos

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Leemos el csv con el que trabajaremos

# %%
Accidentes = pd.read_csv("../Datasets/PrimeraLimpieza_Modificado.csv")
#El documento original deberia ser "PrimeraLimpieza.csv"
#Me habria gustado tener todo el trabajo guardado pero hubo una parte que no guarde, cambie los valores "?" en la columna "dates" por valores "Dia:1" y "mes:jan".
#Lo cual no debería influir en mis conclusiones ya que sigue perteneciendo al mismo año.

# %% [markdown]
# Cambiamos el formato de fecha de excel al formato de fecha datetime

# %%
Accidentes['Date'] = Accidentes['Date'].apply(pd.to_datetime)
datetimes = Accidentes.Date
datetimes
# Out:
# 0      2007-12-31
# 1      2007-12-30
# 2      2007-12-30
# 3      2007-12-27
# 4      2007-12-26
#           ...
# 3038   2022-01-12
# 3039   2022-01-08
# 3040   2022-01-05
# 3041   2022-01-04
# 3042   2022-01-03
# Name: Date, Length: 3043, dtype: datetime64[ns]

# %% [markdown]
# Ordenamos por fecha

# %%
Accidentes = Accidentes.sort_values(by= "Date", ascending=True)
Accidentes
# Out:
#       Unnamed: 0       Date                       Aircraft Model  \
# 220         2822 2007-01-01                       Boeing 737-4Q8
# 219         2823 2007-01-07             Beechcraft A100 King Air
# 218         2824 2007-01-09                   Antonov An-26B-100
# 216         2826 2007-01-09  British Aerospace 3112 Jetstream 31
# 217         2825 2007-01-09                          Learjet 24F
# ...          ...        ...                                  ...
# 3035           7 2022-02-05            Cessna 208B Grand Caravan
# 3034           8 2022-02-08                        Antonov An-26
# 3033           9 2022-02-11                        Antonov An-2R
# 3032          10 2022-02-14                      Let L-410UVP-E3
# 3031          11 2022-02-15      Britten-Norman BN-2A-9 Islander
#
#                        Airline                  Aircraft Type  \
# 220                    AdamAir   Domestic Scheduled Passenger
# ...

# %% [markdown]
# Cambiamos algunas formalidades y eliminamos columnas innecesarias

# %%
Accidentes = Accidentes.fillna("Unknown")

# %%
Accidentes
# Out:
#       Unnamed: 0       Date                       Aircraft Model  \
# 220         2822 2007-01-01                       Boeing 737-4Q8
# 219         2823 2007-01-07             Beechcraft A100 King Air
# 218         2824 2007-01-09                   Antonov An-26B-100
# 216         2826 2007-01-09  British Aerospace 3112 Jetstream 31
# 217         2825 2007-01-09                          Learjet 24F
# ...          ...        ...                                  ...
# 3035           7 2022-02-05            Cessna 208B Grand Caravan
# 3034           8 2022-02-08                        Antonov An-26
# 3033           9 2022-02-11                        Antonov An-2R
# 3032          10 2022-02-14                      Let L-410UVP-E3
# 3031          11 2022-02-15      Britten-Norman BN-2A-9 Islander
#
#                        Airline                  Aircraft Type  \
# 220                    AdamAir   Domestic Scheduled Passenger
# ...

# %%
AccidentesFinal = Accidentes.drop(["Unnamed: 0"], axis="columns")

# %%
AccidentesFinal
# Out:
#            Date                       Aircraft Model  \
# 220  2007-01-01                       Boeing 737-4Q8
# 219  2007-01-07             Beechcraft A100 King Air
# 218  2007-01-09                   Antonov An-26B-100
# 216  2007-01-09  British Aerospace 3112 Jetstream 31
# 217  2007-01-09                          Learjet 24F
# ...         ...                                  ...
# 3035 2022-02-05            Cessna 208B Grand Caravan
# 3034 2022-02-08                        Antonov An-26
# 3033 2022-02-11                        Antonov An-2R
# 3032 2022-02-14                      Let L-410UVP-E3
# 3031 2022-02-15      Britten-Norman BN-2A-9 Islander
#
#                        Airline                  Aircraft Type  \
# 220                    AdamAir   Domestic Scheduled Passenger
# 219              Transwest Air                      Ambulance
# 218       Aeriantur-M Airlines  Int'l Non Scheduled Passenger
# 216                  Peace Air   Domestic Scheduled Passenger
# ...

# %% [markdown]
# Creamos el csv limpio final

# %%
AccidentesFinal.to_csv("LimpiezaFinal.csv")
