# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Accidentes = pd.read_csv("LimpiezaFinal.csv")

# %%
AccidentesFinal = Accidentes.drop(["Unnamed: 0"], axis="columns")

# %%
AccidentesFinal
# Out:
#             Date                       Aircraft Model  \
# 0     2007-01-01                       Boeing 737-4Q8
# 1     2007-01-07             Beechcraft A100 King Air
# 2     2007-01-09                   Antonov An-26B-100
# 3     2007-01-09  British Aerospace 3112 Jetstream 31
# 4     2007-01-09                          Learjet 24F
# ...          ...                                  ...
# 3038  2022-02-05            Cessna 208B Grand Caravan
# 3039  2022-02-08                        Antonov An-26
# 3040  2022-02-11                        Antonov An-2R
# 3041  2022-02-14                      Let L-410UVP-E3
# 3042  2022-02-15      Britten-Norman BN-2A-9 Islander
#
#                        Airline                  Aircraft Type  \
# 0                      AdamAir   Domestic Scheduled Passenger
# 1                Transwest Air                      Ambulance
# 2         Aeriantur-M Airlines  Int'l Non Scheduled Passenger
# 3                    Peace Air   Domestic Scheduled Passenger
# ...

# %%
AccidentesFatales = AccidentesFinal[AccidentesFinal.Fatalities > 0]
AccidentesFatales
# Out:
#             Date                 Aircraft Model                    Airline  \
# 0     2007-01-01                 Boeing 737-4Q8                    AdamAir
# 1     2007-01-07       Beechcraft A100 King Air              Transwest Air
# 2     2007-01-09             Antonov An-26B-100       Aeriantur-M Airlines
# 4     2007-01-09                    Learjet 24F      Ameristar Jet Charter
# 7     2007-01-12         Cessna 525 CitationJet                   SunQuest
# ...          ...                            ...                        ...
# 3021  2021-12-15              Gulfstream G-IVSP    Helidosa Aviation Group
# 3023  2021-12-21  Cessna 208B Super Cargomaster                 Martinaire
# 3024  2021-12-23                 Shorts 360-300              Malu Aviation
# 3026  2021-12-27                    Learjet 35A  Aeromedevac Air Ambulance
# 3040  2022-02-11                  Antonov An-2R         Kamchatsky Krechet
#
#                       Aircraft Type         Incident Type  \
# ...

# %%
AccidentesDomesticos = AccidentesFinal[AccidentesFinal['Aircraft Type'].str.contains("Passenger|Domestic",na=True)]
AccidentesDomesticos
# Out:
#             Date                       Aircraft Model               Airline  \
# 0     2007-01-01                       Boeing 737-4Q8               AdamAir
# 2     2007-01-09                   Antonov An-26B-100  Aeriantur-M Airlines
# 3     2007-01-09  British Aerospace 3112 Jetstream 31             Peace Air
# 6     2007-01-11         CASA/IPTN NC-212 Aviocar 200      Aviastar Mandiri
# 13    2007-01-22                         ATR 42-500 ?          Air Botswana
# ...          ...                                  ...                   ...
# 3031  2022-01-03  British Aerospace 4121 Jetstream 41            SA Airlink
# 3032  2022-01-04  British Aerospace 3101 Jetstream 31                LANHSA
# 3033  2022-01-05                       Boeing 737-4H6      Caspian Airlines
# 3036  2022-01-22                      Airbus A320-232       JetBlue Airways
# 3042  2022-02-15      Britten-Norman BN-2A-9 Islander          Air Flamenco
#
# ...

# %%
AccidentesDomesticos_by_airline = AccidentesDomesticos['Airline'].value_counts(ascending = False) \
                                  .head(15) \
                                  .sort_values(ascending=True) \
                                  .plot(kind='barh', figsize=(15,7))
                                
plt.title('Crashes by Airline',fontsize=30)
plt.ylabel('Airlines', fontsize=20)
plt.xlabel('Number of Crashes', fontsize=20);

plt.savefig("CrashesByAirline.jpg")

# %%
AccidentesDomesticosFatales = AccidentesDomesticos[AccidentesDomesticos.Fatalities > 0]
AccidentesDomesticosFatales
# Out:
#             Date                   Aircraft Model  \
# 0     2007-01-01                   Boeing 737-4Q8
# 2     2007-01-09               Antonov An-26B-100
# 18    2007-01-25                       Fokker 100
# 27    2007-02-06   Beechcraft 200C Super King Air
# 41    2007-03-07                   Boeing 737-497
# ...          ...                              ...
# 2886  2021-01-09              Boeing 737-524 (WL)
# 2913  2021-03-02                   Let L-410UVP-E
# 2957  2021-07-06               Antonov An-26B-100
# 2982  2021-09-12                 Let L-410UVP-E20
# 3013  2021-11-13  Britten-Norman BN-2A-6 Islander
#
#                                               Airline  \
# 0                                             AdamAir
# 2                                Aeriantur-M Airlines
# 18                                           Régional
# 27                                   Air Turks Caicos
# 41                                             Garuda
# ...

# %%
AccidentesDomesticosFatales_by_airline = AccidentesDomesticosFatales['Airline'].value_counts(ascending = False) \
                                  .head(15) \
                                  .sort_values(ascending=True) \
                                  .plot(kind='barh', figsize=(15,7))
                                
plt.title('Fatal Crashes by Airline',fontsize=30)
plt.ylabel('Airlines', fontsize=20)
plt.xlabel('Number of Fatal Crashes', fontsize=20);

plt.savefig("FatalCrashesByAirline.jpg")
